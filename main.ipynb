# %%
name = 'John Doe'
print(f'Hello, {name}!')
# Out:
# Hello, John Doe!

# %%
print('This is a simple Python script that greets the user by name.')
# Out:
# This is a simple Python script that greets the user by name.

# %% [markdown]
# ## Variables

# %%
first_name = 'Jane'
last_name = 'Smith'
age = 30
height = 1.65

gender = 'female'

print(age)
print(first_name + ' ' + last_name)
print(f'{first_name} {last_name} is {age} years old and is {gender}.')
# Out:
# 30
# Jane Smith
# Jane Smith is 30 years old and is female.

# %% [markdown]
# ## Data Types

# %% [markdown]
# ### Strings

# %%
greeting = 'Hello'
#print(greeting)
greeting ='Hi'
print(greeting)

multline_string = '''This is a multi-line string.
It can span multiple lines.'''
print(type(multline_string))
# Out:
# Hi
# <class 'str'>

# %%
print(type(greeting.upper()))
# Out:
# <class 'str'>

# %%
name = "  John Doe  "
print(name)
name = '  John Doe  '
print(name.strip())
# Out:
#   John Doe
# John Doe

# %%
laugh = 'Ha' * 3
print(laugh)
# Out:
# HaHaHa

# %% [markdown]
# ## int

# %%
current_year = 2026
floor_level = -1
score = 90
large_number = 10**100
print(current_year)
# Out:
# 2026

# %% [markdown]
# ## float

# %%
pi = 3.14159
print(pi)
temp = 25.5
stock_price = 150.75
scientific = 2.5e4 #
# Out:
# 3.14159

# %%
name = input('What is your name? ')
print(f'Hello, {name}! Welcome to the Python tutorial.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 name = input('What is your name? ')
#       2 print(f'Hello, {name}! Welcome to the Python tutorial.')
#
# File c:\Users\t490s\26k-zindua\python-projects\tutorial\env\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\t490s\26k-zindua\python-projects\tutorial\env\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
age_input = input('How old are you? ')
age = int(age_input)
print(f'Next year, you will be {age + 1} years old.')
# Out:
# Next year, you will be 21 years old.

# %% [markdown]
# ## Conditional Statements

# %%
age = 18
if age >= 18:
    print('You are an adult.')

# %%
age = 14
if age >= 18:
    print('You are an adult.')  
else:
    print('You are not an adult.')

# %%
score = int(input('Enter your score: '))
if score >= 90:
    print('Grade: A')
elif score >= 70:
    print('Grade: B')
elif score >= 50:
    print('Grade: C')    
else:
    print('Fail')

# %%
age = 20
has_id = True

if age >= 18:
    if has_id:
        print('You can enter the club.')
    else:
        print('You need an ID to enter the club.')

# %%
age = 20
has_ticket = False

if age >= 18 and has_ticket:
    print('Access granted.')
else:
    print('Access denied')
# Out:
# Access denied

# %%
age = 17 
message = 'adult' if age >= 18 else 'minor'
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
age = int(input("Enter your age: "))
has_ticket = input("Do you have a ticket? (yes/no): ").strip().lower() == "yes"
is_vip = input("Are you a VIP? (yes/no): ").strip().lower() == "yes"

if is_vip or (age >= 18 and has_ticket):
        print("Access granted")
else:
        print("Access denied")
# Out:
# Access granted

# %%
students = ['Alice', 'Bob', 'Charlie']
for student in students:
    print('Hello', student)
# Out:
# Hello Alice
# Hello Bob
# Hello Charlie

# %%
count = 0

while count <= 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Loops

# %%
for i in range( 6):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
attempts = 0
while attempts < 3:
    password = input("Enter the password: ")
    if password == "1234":
        print("Login successful")
        break
    else:
        print("Incorrect password")
        attempts += 1
if attempts == 3:

# %% [markdown]
# ## Lists

# %%
my_list = [1, 2, 3, 4, 5]
print(type(my_list))

names = ['Alice', 'Bob', 'Charlie']
print(type(names))
# Out:
# <class 'list'>
# <class 'list'>

# %%
print(names[0])
print(names[-1])
# Out:
# Alice
# Charlie

# %%
names[0] = 'Kinyua'
print(names)
# Out:
# ['Kinyua', 'Bob', 'Charlie']

# %%
names.append('David')
print(names)
# Out:
# ['Kinyua', 'Winstone', 'Bob', 'Charlie', 'David', 'Winstone', 'David', 'David']

# %%
names.insert(1, 'Winstone')
print(names)
# Out:
# ['Kinyua', 'Winstone', 'Winstone', 'Bob', 'Charlie', 'David', 'Winstone', 'David', 'David']

# %%
numbers = [10, 20, 30, 40, 50]
numbers.remove(30)
print(numbers)
numbers.pop(2)
print(numbers)
# Out:
# [10, 20, 40, 50]
# [10, 20, 50]

# %%
names = ['Del', 'Winstone', 'Isaac', 'William', 'Lenny']
for name in names:
    print(name)
# Out:
# Del
# Winstone
# Isaac
# William
# Lenny

# %%
numbers = [80,20, 30, 10, 50, 70, 60]
numbers.sort()
print(numbers)
numbers.reverse()
print (numbers)
# Out:
# [10, 20, 30, 50, 60, 70, 80]
# [80, 70, 60, 50, 30, 20, 10]

# %% [markdown]
# ### Nested Lists

# %%
matrix = [
    [1, 3, 3],
    [4, 5, 6],
    [7, 8, 9]
]
print(matrix[0][1])
# Out:
# 3

# %%
names = ['Alice', 'Bob', 'Charlie']
if 'Alice ' in names:
    print('Alice is in the list.')
else:
    print('Alice is not in the list.')
# Out:
# Alice is not in the list.

# %% [markdown]
# ## Tuples

# %%
my_tuple = (1, 2, 3, 4, 5)
print(type(my_tuple))
print(my_tuple[0])
# Out:
# <class 'tuple'>
# 1

# %%
my_tuple = (1, 2, 3)
print(my_tuple)

my_tuple[1] = 10
# Out:
# (1, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 my_tuple = (1, 2, 3)
#       2 print(my_tuple)
#       3
# ----> 4 my_tuple[1] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
names = ('John')
print(names)
# Out:
# John

# %%
print(my_tuple.count(2))
print(my_tuple.index(3))
# Out:
# 1
# 2

# %%
person = ('John', 20, 'Nairobi')

name,age,city = person
print(name)
# Out:
# John

# %%
data = ["React", "Node", "JavaScript", "Tailwind"]

data.sort()
print(f'Ascending: {data}')
# Out:
# Ascending: ['JavaScript', 'Node', 'React', 'Tailwind']

# %%
list = [1, 2, 3, 4, 5]
total = sum(list)
print(total)
# Out:
# 15

# %%
names = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice']

unique_names = set(names)
print(unique_names)
# Out:
# {'Eve', 'Alice', 'David', 'Charlie', 'Bob'}

# %%
list2 = [23, 45 , 67, -10, 23, 50, -10]
unique_numbers = set(list2)
print(unique_numbers)
# Out:
# {67, 45, 50, -10, 23}

# %%
list1 = [10, 20, 30, 40, 50]

total = sum(list1)

# %%
numbers = (10, 20, 30, 40, 50)
for index, number in enumerate(numbers):
    print(f'Index: {index}, Number: {number}')
# Out:
# Index: 0, Number: 10
# Index: 1, Number: 20
# Index: 2, Number: 30
# Index: 3, Number: 40
# Index: 4, Number: 50

# %%
student = ('Winstone' , 21, 'A')

name, age, grade = student
print(name)
# Out:
# Winstone

# %%
operators = ['+', '-', '*', '/']

print(operators)

choice = input('Choose an operator:')

if choice in operators:
    num1 = float(input('Enter first number: '))
    num2 = float(input('Enter second number: '))
# Out:
# ['+', '-', '*', '/']

# %% [markdown]
# ##  Dictionaries

# %%
student = {
    'name': 'winstone',
    'age': 21,
    'course': 'Python'
}
print(student)
print(student['name'])
print(student.get('city'))
# Out:
# {'name': 'winstone', 'age': 21, 'course': 'Python'}
# winstone
# None

# %%
student['email'] = 'winstonemuna404@gmail.com'
student['age'] = 20
print(student)

student.pop('age', None)
print(student)
del student['email']
print(student)
# Out:
# {'name': 'winstone', 'email': 'winstonemuna404@gmail.com', 'age': 20}
# {'name': 'winstone', 'email': 'winstonemuna404@gmail.com'}
# {'name': 'winstone'}

# %%
for key in student:
    print(key, student[key])
# Out:
# name winstone

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name winstone

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name'])
# dict_values(['winstone'])
# dict_items([('name', 'winstone')])

# %%
students = [
    {
        'id' : 121,
        'name' : 'winstone',
        'age' : 21,
        'course' : 'Python'
    },
     {
        'id' : 121,
        'name' : 'Del',
        'age' : 28,
        'course' : 'OOPs'
    },
     {
        'id' : 121,
        'name' : 'Ezekiel',
        'age' : 30,
        'course' : 'Software Engineering'
    },
     {
        'id' : 120,
        'name' : 'Alice',
        'age' : 29,
        'course' : 'Data Science'
    },
]
print(students)
# Out:
# [{'id': 121, 'name': 'winstone', 'age': 21, 'course': 'Python'}, {'id': 121, 'name': 'Del', 'age': 28, 'course': 'OOPs'}, {'id': 121, 'name': 'Ezekiel', 'age': 30, 'course': 'Software Engineering'}, {'id': 120, 'name': 'Alice', 'age': 29, 'course': 'Data Science'}]

# %%
# Set of integers
ids = {101, 102, 103}

# Set of mixed immutable types
mixed = {1, "Hello", 3.14, (1, 2)}

# %%
A = {1, 2}
B = {2, 3}
print(A | B)       # {1, 2, 3}
print(A.union(B))  # {1, 2, 3}
# Out:
# {1, 2, 3}
# {1, 2, 3}

# %%
A = {1, 2, 3}
B = {2, 3, 4}
print(A - B) # {1} (Items in A that are not in B)
print(B - A) # {4} (Items in B that are not in A)
# Out:
# {1}
# {4}
