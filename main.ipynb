# %%
name = 'John Doe'
print(f'Hello, {name}!')
# Out:
# Hello, John Doe!

# %%
print('This is a simple Python script that greets the user by name.')
# Out:
# This is a simple Python script that greets the user by name.

# %% [markdown]
# ## Variables
